# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Placement_Prediction_data.csv')

# %%
df
# Out:
#       Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0          1   7.5               1                        1
# 1              1          2   8.9               0                        3
# 2              2          3   7.3               1                        2
# 3              3          4   7.5               1                        1
# 4              4          5   8.3               1                        2
# ...          ...        ...   ...             ...                      ...
# 9995        9995       9996   7.5               1                        1
# 9996        9996       9997   7.4               0                        1
# 9997        9997       9998   8.4               1                        3
# 9998        9998       9999   8.9               0                        3
# 9999        9999      10000   8.4               0                        1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# 1                 2       9                         4.0        Yes       Yes
# 2                 2       8                         4.8        Yes        No
# 3                 2       8                         4.4        Yes       Yes
# 4                 2       8                         4.5        Yes       Yes
# ...             ...     ...                         ...        ...       ...
# 9995              2       7                         3.9        Yes        No
# 9996              0       9                         4.8         No        No
# 9997              0       7                         4.8        Yes       Yes
# 9998              2       8                         4.8        Yes       Yes
# 9999              1       6                         3.8         No        No
#
#       12th Percentage  10th Percentage  backlogs PlacementStatus
# 0                  61               79         2       NotPlaced
# 1                  78               82         0          Placed
# 2                  79               80         2       NotPlaced
# 3                  81               80         0          Placed
# 4                  74               88         0          Placed
# ...               ...              ...       ...             ...
# 9995               85               66         4       NotPlaced
# 9996               84               67         1          Placed
# 9997               79               81         0          Placed
# 9998               71               85         0          Placed
# 9999               62               66         1       NotPlaced
#
# [10000 rows x 14 columns]

# %%
df.rename(columns={'Communication Skill Rating':'communi_rating',
                   'Workshops/Certificatios':'workshops'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.rename(columns={'Communication Skill Rating':'communi_rating','Workshops/Certificatios':'workshops'},inplace=True)
#
# NameError: name 'df' is not defined

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#       StudentId  CGPA  Major Projects  workshops  Mini Projects  Skills  \
# 0             1   7.5               1          1              1       6
# 1             2   8.9               0          3              2       9
# 2             3   7.3               1          2              2       8
# 3             4   7.5               1          1              2       8
# 4             5   8.3               1          2              2       8
# ...         ...   ...             ...        ...            ...     ...
# 9995       9996   7.5               1          1              2       7
# 9996       9997   7.4               0          1              0       9
# 9997       9998   8.4               1          3              0       7
# 9998       9999   8.9               0          3              2       8
# 9999      10000   8.4               0          1              1       6
#
#       communi_rating Internship Hackathon  12th Percentage  10th Percentage  \
# 0                4.4         No        No               61               79
# 1                4.0        Yes       Yes               78               82
# 2                4.8        Yes        No               79               80
# 3                4.4        Yes       Yes               81               80
# 4                4.5        Yes       Yes               74               88
# ...              ...        ...       ...              ...              ...
# 9995             3.9        Yes        No               85               66
# 9996             4.8         No        No               84               67
# 9997             4.8        Yes       Yes               79               81
# 9998             4.8        Yes       Yes               71               85
# 9999             3.8         No        No               62               66
#
#       backlogs PlacementStatus
# 0            2       NotPlaced
# 1            0          Placed
# 2            2       NotPlaced
# 3            0          Placed
# 4            0          Placed
# ...        ...             ...
# 9995         4       NotPlaced
# 9996         1          Placed
# 9997         0          Placed
# 9998         0          Placed
# 9999         1       NotPlaced
#
# [10000 rows x 13 columns]

# %%
df.fillna(0,inplace=True)
# Out:
#       StudentId  CGPA  Major Projects  workshops  Mini Projects  Skills  \
# 0             1   7.5               1          1              1       6
# 1             2   8.9               0          3              2       9
# 2             3   7.3               1          2              2       8
# 3             4   7.5               1          1              2       8
# 4             5   8.3               1          2              2       8
# ...         ...   ...             ...        ...            ...     ...
# 9995       9996   7.5               1          1              2       7
# 9996       9997   7.4               0          1              0       9
# 9997       9998   8.4               1          3              0       7
# 9998       9999   8.9               0          3              2       8
# 9999      10000   8.4               0          1              1       6
#
#       communi_rating Internship Hackathon  12th Percentage  10th Percentage  \
# 0                4.4         No        No               61               79
# 1                4.0        Yes       Yes               78               82
# 2                4.8        Yes        No               79               80
# 3                4.4        Yes       Yes               81               80
# 4                4.5        Yes       Yes               74               88
# ...              ...        ...       ...              ...              ...
# 9995             3.9        Yes        No               85               66
# 9996             4.8         No        No               84               67
# 9997             4.8        Yes       Yes               79               81
# 9998             4.8        Yes       Yes               71               85
# 9999             3.8         No        No               62               66
#
#       backlogs PlacementStatus
# 0            2       NotPlaced
# 1            0          Placed
# 2            2       NotPlaced
# 3            0          Placed
# 4            0          Placed
# ...        ...             ...
# 9995         4       NotPlaced
# 9996         1          Placed
# 9997         0          Placed
# 9998         0          Placed
# 9999         1       NotPlaced
#
# [10000 rows x 13 columns]

# %%
df
# Out:
#       StudentId  CGPA  Major Projects  workshops  Mini Projects  Skills  \
# 0             1   7.5               1          1              1       6
# 1             2   8.9               0          3              2       9
# 2             3   7.3               1          2              2       8
# 3             4   7.5               1          1              2       8
# 4             5   8.3               1          2              2       8
# ...         ...   ...             ...        ...            ...     ...
# 9995       9996   7.5               1          1              2       7
# 9996       9997   7.4               0          1              0       9
# 9997       9998   8.4               1          3              0       7
# 9998       9999   8.9               0          3              2       8
# 9999      10000   8.4               0          1              1       6
#
#       communi_rating Internship Hackathon  12th Percentage  10th Percentage  \
# 0                4.4         No        No               61               79
# 1                4.0        Yes       Yes               78               82
# 2                4.8        Yes        No               79               80
# 3                4.4        Yes       Yes               81               80
# 4                4.5        Yes       Yes               74               88
# ...              ...        ...       ...              ...              ...
# 9995             3.9        Yes        No               85               66
# 9996             4.8         No        No               84               67
# 9997             4.8        Yes       Yes               79               81
# 9998             4.8        Yes       Yes               71               85
# 9999             3.8         No        No               62               66
#
#       backlogs PlacementStatus
# 0            2       NotPlaced
# 1            0          Placed
# 2            2       NotPlaced
# 3            0          Placed
# 4            0          Placed
# ...        ...             ...
# 9995         4       NotPlaced
# 9996         1          Placed
# 9997         0          Placed
# 9998         0          Placed
# 9999         1       NotPlaced
#
# [10000 rows x 13 columns]

# %%
df= pd.read_csv("Salary_prediction_data.csv")
df.head()
# Out:
#    Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0           0          1   7.5               1                        1
# 1           1          2   8.9               0                        3
# 2           2          3   7.3               1                        2
# 3           3          4   7.5               1                        1
# 4           4          5   8.3               1                        2
#
#    Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0              1       6                         4.4         No        No
# 1              2       9                         4.0        Yes       Yes
# 2              2       8                         4.8        Yes        No
# 3              2       8                         4.4        Yes       Yes
# 4              2       8                         4.5        Yes       Yes
#
#    12th Percentage  10th Percentage  backlogs PlacementStatus   salary
# 0               61               79         2       NotPlaced        0
# 1               78               82         0          Placed  1000000
# 2               79               80         2       NotPlaced        0
# 3               81               80         0          Placed   950000
# 4               74               88         0          Placed   950000

# %%
x=df.drop(['StudentId','PlacementStatus','salary'],axis=1)

# %%
x
# Out:
#       Unnamed: 0  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0   7.5               1                        1
# 1              1   8.9               0                        3
# 2              2   7.3               1                        2
# 3              3   7.5               1                        1
# 4              4   8.3               1                        2
# ...          ...   ...             ...                      ...
# 9995        9995   7.5               1                        1
# 9996        9996   7.4               0                        1
# 9997        9997   8.4               1                        3
# 9998        9998   8.9               0                        3
# 9999        9999   8.4               0                        1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# 1                 2       9                         4.0        Yes       Yes
# 2                 2       8                         4.8        Yes        No
# 3                 2       8                         4.4        Yes       Yes
# 4                 2       8                         4.5        Yes       Yes
# ...             ...     ...                         ...        ...       ...
# 9995              2       7                         3.9        Yes        No
# 9996              0       9                         4.8         No        No
# 9997              0       7                         4.8        Yes       Yes
# 9998              2       8                         4.8        Yes       Yes
# 9999              1       6                         3.8         No        No
#
#       12th Percentage  10th Percentage  backlogs
# 0                  61               79         2
# 1                  78               82         0
# 2                  79               80         2
# 3                  81               80         0
# 4                  74               88         0
# ...               ...              ...       ...
# 9995               85               66         4
# 9996               84               67         1
# 9997               79               81         0
# 9998               71               85         0
# 9999               62               66         1
#
# [10000 rows x 12 columns]

# %%
y = df['PlacementStatus']

# %%
y
# Out:
# 0       NotPlaced
# 1          Placed
# 2       NotPlaced
# 3          Placed
# 4          Placed
#           ...
# 9995    NotPlaced
# 9996       Placed
# 9997       Placed
# 9998       Placed
# 9999    NotPlaced
# Name: PlacementStatus, Length: 10000, dtype: str

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.4.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
x['Internship'] = le.fit_transform(x['Internship'])
x['Hackathon'] = le.fit_transform(x['Hackathon'])

# %%
y=le.fit_transform(y)

# %%
y
# Out:
# array([0, 1, 0, ..., 1, 1, 0], shape=(10000,))

# %%
x
# Out:
#       Unnamed: 0  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0   7.5               1                        1
# 1              1   8.9               0                        3
# 2              2   7.3               1                        2
# 3              3   7.5               1                        1
# 4              4   8.3               1                        2
# ...          ...   ...             ...                      ...
# 9995        9995   7.5               1                        1
# 9996        9996   7.4               0                        1
# 9997        9997   8.4               1                        3
# 9998        9998   8.9               0                        3
# 9999        9999   8.4               0                        1
#
#       Mini Projects  Skills  Communication Skill Rating  Internship  \
# 0                 1       6                         4.4           0
# 1                 2       9                         4.0           1
# 2                 2       8                         4.8           1
# 3                 2       8                         4.4           1
# 4                 2       8                         4.5           1
# ...             ...     ...                         ...         ...
# 9995              2       7                         3.9           1
# 9996              0       9                         4.8           0
# 9997              0       7                         4.8           1
# 9998              2       8                         4.8           1
# 9999              1       6                         3.8           0
#
#       Hackathon  12th Percentage  10th Percentage  backlogs
# 0             0               61               79         2
# 1             1               78               82         0
# 2             0               79               80         2
# 3             1               81               80         0
# 4             1               74               88         0
# ...         ...              ...              ...       ...
# 9995          0               85               66         4
# 9996          0               84               67         1
# 9997          1               79               81         0
# 9998          1               71               85         0
# 9999          0               62               66         1
#
# [10000 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %%
x_train
# Out:
#       Unnamed: 0  CGPA  Major Projects  Workshops/Certificatios  \
# 1191        1191   7.8               1                        2
# 4458        4458   8.7               2                        2
# 1131        1131   8.6               2                        3
# 9562        9562   7.8               1                        1
# 6579        6579   7.8               1                        2
# ...          ...   ...             ...                      ...
# 350          350   7.5               1                        2
# 79            79   7.6               1                        2
# 8039        8039   8.2               2                        3
# 6936        6936   7.6               1                        2
# 5640        5640   6.6               0                        2
#
#       Mini Projects  Skills  Communication Skill Rating  Internship  \
# 1191              1       7                         4.1           0
# 4458              2       9                         4.7           1
# 1131              2       9                         4.8           1
# 9562              0       6                         4.6           0
# 6579              1       7                         4.3           0
# ...             ...     ...                         ...         ...
# 350               0       7                         3.7           0
# 79                1       7                         3.9           0
# 8039              2       8                         4.8           1
# 6936              0       6                         4.1           0
# 5640              1       6                         4.1           0
#
#       Hackathon  12th Percentage  10th Percentage  backlogs
# 1191          1               55               63         4
# 4458          1               76               85         0
# 1131          1               73               80         0
# 9562          0               58               80         2
# 6579          0               55               68         4
# ...         ...              ...              ...       ...
# 350           1               55               66         2
# 79            1               58               66         2
# 8039          1               77               83         1
# 6936          1               55               64         4
# 5640          0               57               62         3
#
# [7000 rows x 12 columns]

# %%
x_test
# Out:
#       Unnamed: 0  CGPA  Major Projects  Workshops/Certificatios  \
# 8018        8018   6.7               1                        2
# 9225        9225   7.7               1                        2
# 3854        3854   8.4               1                        2
# 2029        2029   7.6               1                        1
# 3539        3539   8.6               2                        3
# ...          ...   ...             ...                      ...
# 4208        4208   6.5               0                        2
# 5335        5335   7.4               1                        1
# 2554        2554   8.2               2                        3
# 13            13   7.7               1                        1
# 4468        4468   8.0               2                        3
#
#       Mini Projects  Skills  Communication Skill Rating  Internship  \
# 8018              0       6                         3.9           0
# 9225              2       8                         3.9           1
# 3854              0       9                         4.7           1
# 2029              0       7                         4.1           0
# 3539              0       7                         4.2           1
# ...             ...     ...                         ...         ...
# 4208              1       8                         4.8           0
# 5335              0       6                         3.7           0
# 2554              2       9                         4.1           1
# 13                1       7                         4.6           0
# 4468              2       9                         4.8           1
#
#       Hackathon  12th Percentage  10th Percentage  backlogs
# 8018          0               59               69         2
# 9225          1               81               75         4
# 3854          1               55               81         1
# 2029          1               55               64         4
# 3539          1               79               86         0
# ...         ...              ...              ...       ...
# 4208          1               74               84         0
# 5335          0               63               64         3
# 2554          1               73               69         1
# 13            1               63               73         3
# 4468          1               82               81         0
#
# [3000 rows x 12 columns]

# %%
y_train
# Out:
# array([0, 1, 1, ..., 1, 0, 0], shape=(7000,))

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(3000,))

# %%
from sklearn.ensemble import RandomForestClassifier
classify= RandomForestClassifier(n_estimators= 100, criterion="entropy",max_depth=2)
classify.fit(x_train, y_train)
ypred=classify.predict(x_test)

# %%
ypred
# Out:
# array([0, 0, 1, ..., 1, 0, 1], shape=(3000,))

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(3000,))

# %%
ypred
# Out:
# array([0, 0, 1, ..., 1, 0, 1], shape=(3000,))

# %%
from sklearn import metrics

# %%
accuracy_score=metrics.accuracy_score(y_test,ypred)

# %%
accuracy_score
# Out:
# 0.87

# %%
confusion_metrix=metrics.confusion_matrix(y_test,ypred)

# %%
confusion_metrix
# Out:
# array([[1553,  221],
#        [ 169, 1057]])

# %%
classification_report=metrics.classification_report(y_test,ypred)

# %%
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.90      0.88      0.89      1774\n           1       0.83      0.86      0.84      1226\n\n    accuracy                           0.87      3000\n   macro avg       0.86      0.87      0.87      3000\nweighted avg       0.87      0.87      0.87      3000\n'

# %%
importances = RandomForestClassifier.feature_importances_

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in .\.venv\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 66.6 kB/s eta 0:01:38
#    -- ------------------------------------- 0.5/7.0 MB 66.6 kB/s eta 0:01:38
#    -- ------------------------------------- 0.5/7.0 MB 66.6 kB/s eta 0:01:38
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ---- ----------------------------------- 0.8/7.0 MB 115.7 kB/s eta 0:00:54
#    ----- ---------------------------------- 1.0/7.0 MB 97.2 kB/s eta 0:01:02
#    ----- ---------------------------------- 1.0/7.0 MB 97.2 kB/s eta 0:01:02
#    ----- ---------------------------------- 1.0/7.0 MB 97.2 kB/s eta 0:01:02
#    ----- ---------------------------------- 1.0/7.0 MB 97.2 kB/s eta 0:01:02
#    ----- ---------------------------------- 1.0/7.0 MB 97.2 kB/s eta 0:01:02
#    ------- -------------------------------- 1.3/7.0 MB 116.1 kB/s eta 0:00:50
#    ------- -------------------------------- 1.3/7.0 MB 116.1 kB/s eta 0:00:50
#    ------- -------------------------------- 1.3/7.0 MB 116.1 kB/s eta 0:00:50
#    -------- ------------------------------- 1.6/7.0 MB 134.0 kB/s eta 0:00:41
#    -------- ------------------------------- 1.6/7.0 MB 134.0 kB/s eta 0:00:41
#    -------- ------------------------------- 1.6/7.0 MB 134.0 kB/s eta 0:00:41
#    ---------- ----------------------------- 1.8/7.0 MB 150.2 kB/s eta 0:00:35
#    ---------- ----------------------------- 1.8/7.0 MB 150.2 kB/s eta 0:00:35
#    ---------- ----------------------------- 1.8/7.0 MB 150.2 kB/s eta 0:00:35
#    ---------- ----------------------------- 1.8/7.0 MB 150.2 kB/s eta 0:00:35
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ----------- ---------------------------- 2.1/7.0 MB 164.0 kB/s eta 0:00:31
#    ------------- -------------------------- 2.4/7.0 MB 148.6 kB/s eta 0:00:32
#    ------------- -------------------------- 2.4/7.0 MB 148.6 kB/s eta 0:00:32
#    ------------- -------------------------- 2.4/7.0 MB 148.6 kB/s eta 0:00:32
#    -------------- ------------------------- 2.6/7.0 MB 158.4 kB/s eta 0:00:28
#    -------------- ------------------------- 2.6/7.0 MB 158.4 kB/s eta 0:00:28
#    -------------- ------------------------- 2.6/7.0 MB 158.4 kB/s eta 0:00:28
#    -------------- ------------------------- 2.6/7.0 MB 158.4 kB/s eta 0:00:28
#    -------------- ------------------------- 2.6/7.0 MB 158.4 kB/s eta 0:00:28
#    -------------- ------------------------- 2.6/7.0 MB 158.4 kB/s eta 0:00:28
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
#    ---------------- ----------------------- 2.9/7.0 MB 163.4 kB/s eta 0:00:26
# Resuming download pillow-12.1.1-cp312-cp312-win_amd64.whl (2.9 MB/7.0 MB)
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
# Resuming download pillow-12.1.1-cp312-cp312-win_amd64.whl (2.9 MB/7.0 MB)
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB ? eta -:--:--
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ----------------- ---------------------- 3.1/7.0 MB 114.2 kB/s eta 0:00:35
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    ------------------- -------------------- 3.4/7.0 MB 87.6 kB/s eta 0:00:42
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    -------------------- ------------------- 3.7/7.0 MB 97.7 kB/s eta 0:00:35
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ---------------------- ----------------- 3.9/7.0 MB 80.0 kB/s eta 0:00:39
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ----------------------- ---------------- 4.2/7.0 MB 84.1 kB/s eta 0:00:34
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    ------------------------- -------------- 4.5/7.0 MB 90.8 kB/s eta 0:00:29
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    -------------------------- ------------- 4.7/7.0 MB 97.8 kB/s eta 0:00:24
#    ---------------------------- ----------- 5.0/7.0 MB 103.2 kB/s eta 0:00:20
#    ---------------------------- ----------- 5.0/7.0 MB 103.2 kB/s eta 0:00:20
#    ---------------------------- ----------- 5.0/7.0 MB 103.2 kB/s eta 0:00:20
#    ---------------------------- ----------- 5.0/7.0 MB 103.2 kB/s eta 0:00:20
#    ---------------------------- ----------- 5.0/7.0 MB 103.2 kB/s eta 0:00:20
#    ----------------------------- ---------- 5.2/7.0 MB 110.4 kB/s eta 0:00:17
#    ----------------------------- ---------- 5.2/7.0 MB 110.4 kB/s eta 0:00:17
#    ----------------------------- ---------- 5.2/7.0 MB 110.4 kB/s eta 0:00:17
#    ----------------------------- ---------- 5.2/7.0 MB 110.4 kB/s eta 0:00:17
#    ----------------------------- ---------- 5.2/7.0 MB 110.4 kB/s eta 0:00:17
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    ------------------------------- -------- 5.5/7.0 MB 117.2 kB/s eta 0:00:14
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    -------------------------------- ------- 5.8/7.0 MB 119.0 kB/s eta 0:00:11
#    ---------------------------------- ----- 6.0/7.0 MB 121.4 kB/s eta 0:00:09
#    ---------------------------------- ----- 6.0/7.0 MB 121.4 kB/s eta 0:00:09
#    ---------------------------------- ----- 6.0/7.0 MB 121.4 kB/s eta 0:00:09
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 6.3/7.0 MB 128.4 kB/s eta 0:00:06
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    ------------------------------------- -- 6.6/7.0 MB 128.5 kB/s eta 0:00:04
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.0 MB 131.4 kB/s eta 0:00:02
#    ---------------------------------------- 7.0/7.0 MB 133.2 kB/s  0:00:31
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (2.9 MB/7.0 MB, attempt 1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /packages/3d/17/688626d192d7261bbbf98846fc98995726bddc2c945344b65bec3a29d731/pillow-12.1.1-cp312-cp312-win_amd64.whl
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (2.9 MB/7.0 MB, attempt 2)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/3d/17/688626d192d7261bbbf98846fc98995726bddc2c945344b65bec3a29d731/pillow-12.1.1-cp312-cp312-win_amd64.whl
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/3d/17/688626d192d7261bbbf98846fc98995726bddc2c945344b65bec3a29d731/pillow-12.1.1-cp312-cp312-win_amd64.whl

# %%
import matplotlib.pyplot as plt

# %%
importances = classify.feature_importances_

# %%
plt.figure(figsize=(10,6))

# %%
plt.bar(x.columns, importances)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Feature Importance for Random Forest Classifier')
plt.xticks(rotation=90) 
plt.show()

# %%
ypred_pob=classify.predict_proba(x_test)[:, 1] 
fpr, tpr, thresholds = metrics.roc_curve(y_test, ypred_pob)
roc_auc = metrics.auc(fpr, tpr)
roc_auc
# Out:
# 0.9414669202234192

# %%
ypred_pob
# Out:
# array([0.07117178, 0.24139219, 0.65501897, ..., 0.6432933 , 0.08792046,
#        0.84212274], shape=(3000,))

# %%
roc_auc = metrics.auc(fpr,tpr) 
roc_auc
# Out:
# 0.9414669202234192

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' %roc_auc )
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve for Random Forest Classifier (Placement Opportunities)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
ypred=knn.predict(x_test)

# %%
ypred
# Out:
# array([0, 1, 0, ..., 0, 0, 1], shape=(3000,))

# %%
accuracy_score=metrics.accuracy_score(y_test,ypred)

# %%
accuracy_score
# Out:
# 0.7253333333333334

# %%
confusion_metrix=metrics.confusion_matrix(y_test,ypred)

# %%
confusion_metrix
# Out:
# array([[1370,  404],
#        [ 420,  806]])

# %%
classification_report=metrics.classification_report(y_test,ypred)

# %%
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.77      0.77      0.77      1774\n           1       0.67      0.66      0.66      1226\n\n    accuracy                           0.73      3000\n   macro avg       0.72      0.71      0.72      3000\nweighted avg       0.72      0.73      0.73      3000\n'

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(random_state=42)

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
ypred=clf.predict(x_test)

# %%
accuracy_score=metrics.accuracy_score(y_test,ypred)

# %%
accuracy_score
# Out:
# 0.9243333333333333

# %%
confusion_metrix=metrics.confusion_matrix(y_test,ypred)

# %%
confusion_metrix
# Out:
# array([[1655,  119],
#        [ 108, 1118]])

# %%
classification_report=metrics.classification_report(y_test,ypred)

# %%
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.94      0.93      0.94      1774\n           1       0.90      0.91      0.91      1226\n\n    accuracy                           0.92      3000\n   macro avg       0.92      0.92      0.92      3000\nweighted avg       0.92      0.92      0.92      3000\n'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
